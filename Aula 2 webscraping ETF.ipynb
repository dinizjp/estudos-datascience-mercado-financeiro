# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (3.8.5)
# Requirement already satisfied: tqdm in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (4.64.1)
# Requirement already satisfied: packaging in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (21.3)
# Requirement already satisfied: requests in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (2.28.1)
# Requirement already satisfied: python-dotenv in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (0.21.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from packaging->webdriver-manager) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (1.26.11)

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (4.8.0)
# Requirement already satisfied: trio~=0.17 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from selenium) (2022.9.24)
# Requirement already satisfied: idna in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: outcome in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: async-generator>=1.9 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /Users/joaopedrodiniz/opt/anaconda3/lib/python3.9/site-packages (from html5lib) (0.5.1)

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service 
from webdriver_manager.chrome import ChromeDriverManager
import time 
import pandas as pd

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

url = "https://www.etf.com/etfanalytics/etf-finder"

driver.get(url)

# %% [markdown]
# # Processo de dados
# * abrir site
# * mudar vizualização para 100
# * Ler tabela
# * Avançar todas as paginas
# * Trocar para outra categoria
# * ler todas as tabelas da categoria

# %%
time.sleep(10)

botao_100 = driver.find_element("xpath", '''html/body/div[5]/section/div/div[3]/section/div
                                                /div/div/div/div[2]/
                                section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span''')
 
driver.execute_script("arguments[0].click();", botao_100)

# %%
numero_paginas = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/
section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/label[2]''')

numero_paginas = numero_paginas.text.replace("of ", "")

numero_paginas = int(numero_paginas)

print(numero_paginas)
# Out:
# 32

# %%
lista__de_tabelas_por_pagina = []
for pagina in range(0, numero_paginas):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/
                                    div/div/div/div[2]/section[2]/div[2]/div/table ''' )

    html_tabela = tabela.get_attribute("outerHTML")

    tabela_final = pd.read_html(html_tabela)[0]

    lista__de_tabelas_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element("xpath",'//*[@id="nextPage"] ')
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina) 
    
base_de_dados_completa = pd.concat(lista__de_tabelas_por_pagina)  

display(base_de_dados_completa)
# Out:
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VTI                    Vanguard Total Stock Market ETF
# 3     VOO                               Vanguard S&P 500 ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 8    CVSB           Calvert Ultra-Short Investment Grade ETF
# 9    CVLC    Calvert US Large-Cap Core Responsible Index ETF
# 10   CVMC      Calvert US Mid-Cap Core Responsible Index ETF
# 11   CVIE        Calvert International Responsible Index ETF
# 12   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 8   Fixed Income: Global - Broad Market, Broad-bas...
# 9                            Equity: U.S. - Large Cap
# 10                             Equity: U.S. - Mid Cap
# 11      Equity: Developed Markets Ex-U.S. - Large Cap
# 12                           Equity: U.S. - Large Cap
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $379.11B
# 1                      Blackrock         0.03%  $310.04B
# 2                       Vanguard         0.03%  $284.32B
# 3                       Vanguard         0.03%  $282.26B
# 4                        Invesco         0.20%  $161.85B
# ..                           ...           ...       ...
# 8                 Morgan Stanley         0.24%        --
# 9                 Morgan Stanley            --        --
# 10                Morgan Stanley         0.15%        --
# 11                Morgan Stanley            --        --
# 12                Morgan Stanley            --        --
#
# [3113 rows x 6 columns]

# %%
 #primeiro coisa é mudar aba 

botao_aba = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/
                                    div/div/div/div[2]/section[2]/div[2]/ul/li[2]/span''')

driver.execute_script("arguments[0].click();", botao_aba)

#voltando para primeira pag 

for pagina in range(0, numero_paginas):
    
    botao_voltar_pagina = driver.find_element("xpath", '//*[@id="previousPage"]')
    
    driver.execute_script("arguments[0].click();", botao_voltar_pagina)

# %%
lista__de_tabelas_por_pagina = []
for pagina in range(0, numero_paginas):
    
    tabela = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/
                                    div/div/div/div[2]/section[2]/div[2]/div/table ''' )

    html_tabela = tabela.get_attribute("outerHTML")

    tabela_final = pd.read_html(html_tabela)[0]

    lista__de_tabelas_por_pagina.append(tabela_final)
    
    botao_avancar_pagina = driver.find_element("xpath",'//*[@id="nextPage"] ')
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina) 
    
base_de_dados_performance = pd.concat(lista__de_tabelas_por_pagina)  

display(base_de_dados_performance)
# Out:
#    Ticker                                               Name 1 Month 3 Month  \
# 0     SPY                             SPDR S&P 500 ETF Trust   4.96%   9.32%
# 1     IVV                           iShares Core S&P 500 ETF   5.01%   9.33%
# 2     VTI                    Vanguard Total Stock Market ETF   5.42%   9.66%
# 3     VOO                               Vanguard S&P 500 ETF   4.99%   9.31%
# 4     QQQ                                  Invesco QQQ Trust  11.51%  14.85%
# ..    ...                                                ...     ...     ...
# 8    CVSB           Calvert Ultra-Short Investment Grade ETF      --      --
# 9    CVLC    Calvert US Large-Cap Core Responsible Index ETF      --      --
# 10   CVMC      Calvert US Mid-Cap Core Responsible Index ETF      --      --
# 11   CVIE        Calvert International Responsible Index ETF      --      --
# 12   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...      --      --
#
#        YTD   1 Year 3 Years 5 Years 10 Years As Of Date
# 0    6.45%   -9.58%   8.73%  11.15%   12.44%   02/09/23
# 1    6.47%   -9.55%   8.74%  11.17%   12.50%   02/09/23
# 2    7.03%  -10.06%   8.29%  10.66%   12.08%   02/09/23
# 3    6.48%   -9.57%   8.71%  11.17%   12.50%   02/09/23
# 4   13.29%  -17.13%  10.27%  14.91%   17.15%   02/09/23
# ..     ...      ...     ...     ...      ...        ...
# 8       --       --      --      --       --   02/09/23
# 9       --       --      --      --       --   02/09/23
# 10      --       --      --      --       --   02/09/23
# 11      --       --      --      --       --   02/09/23
# 12      --       --      --      --       --   02/09/23
#
# [3113 rows x 10 columns]

# %%
driver.quit()

# %%
base_de_dados_completa = base_de_dados_completa.set_index("Ticker")

base_de_dados_completa
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# VOO                                  Vanguard S&P 500 ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVSB             Calvert Ultra-Short Investment Grade ETF
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# CVSB    Fixed Income: Global - Broad Market, Broad-bas...
# CVLC                             Equity: U.S. - Large Cap
# CVMC                               Equity: U.S. - Mid Cap
# CVIE        Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                             Equity: U.S. - Large Cap
#
#                               Issuer Expense Ratio       AUM
# Ticker
# SPY     State Street Global Advisors         0.09%  $379.11B
# IVV                        Blackrock         0.03%  $310.04B
# VTI                         Vanguard         0.03%  $284.32B
# VOO                         Vanguard         0.03%  $282.26B
# QQQ                          Invesco         0.20%  $161.85B
# ...                              ...           ...       ...
# CVSB                  Morgan Stanley         0.24%        --
# CVLC                  Morgan Stanley            --        --
# CVMC                  Morgan Stanley         0.15%        --
# CVIE                  Morgan Stanley            --        --
# CDEI                  Morgan Stanley            --        --
#
# [3113 rows x 5 columns]

# %%
base_de_dados_performance = base_de_dados_performance.set_index("Ticker")
base_de_dados_performance = base_de_dados_performance[['1 Year', '5 Years', '10 Years']]

base_de_dados_performance
# Out:
#          1 Year 5 Years 10 Years
# Ticker
# SPY      -9.58%  11.15%   12.44%
# IVV      -9.55%  11.17%   12.50%
# VTI     -10.06%  10.66%   12.08%
# VOO      -9.57%  11.17%   12.50%
# QQQ     -17.13%  14.91%   17.15%
# ...         ...     ...      ...
# CVSB         --      --       --
# CVLC         --      --       --
# CVMC         --      --       --
# CVIE         --      --       --
# CDEI         --      --       --
#
# [3113 rows x 3 columns]

# %%
base_de_dados_final = base_de_dados_completa.join(base_de_dados_performance)

# %%
base_de_dados_final
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# VOO                                  Vanguard S&P 500 ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVSB             Calvert Ultra-Short Investment Grade ETF
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# CVSB    Fixed Income: Global - Broad Market, Broad-bas...
# CVLC                             Equity: U.S. - Large Cap
# CVMC                               Equity: U.S. - Mid Cap
# CVIE        Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                             Equity: U.S. - Large Cap
#
#                               Issuer Expense Ratio       AUM   1 Year 5 Years  \
# Ticker
# SPY     State Street Global Advisors         0.09%  $379.11B   -9.58%  11.15%
# IVV                        Blackrock         0.03%  $310.04B   -9.55%  11.17%
# VTI                         Vanguard         0.03%  $284.32B  -10.06%  10.66%
# VOO                         Vanguard         0.03%  $282.26B   -9.57%  11.17%
# QQQ                          Invesco         0.20%  $161.85B  -17.13%  14.91%
# ...                              ...           ...       ...      ...     ...
# CVSB                  Morgan Stanley         0.24%        --       --      --
# CVLC                  Morgan Stanley            --        --       --      --
# CVMC                  Morgan Stanley         0.15%        --       --      --
# CVIE                  Morgan Stanley            --        --       --      --
# CDEI                  Morgan Stanley            --        --       --      --
#
#        10 Years
# Ticker
# SPY      12.44%
# IVV      12.50%
# VTI      12.08%
# VOO      12.50%
# QQQ      17.15%
# ...         ...
# CVSB         --
# CVLC         --
# CVMC         --
# CVIE         --
# CDEI         --
#
# [3113 rows x 8 columns]

# %%
display(base_de_dados_completa)
display(base_de_dados_performance)
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# VOO                                  Vanguard S&P 500 ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVSB             Calvert Ultra-Short Investment Grade ETF
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# CVSB    Fixed Income: Global - Broad Market, Broad-bas...
# CVLC                             Equity: U.S. - Large Cap
# CVMC                               Equity: U.S. - Mid Cap
# CVIE        Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                             Equity: U.S. - Large Cap
#
#                               Issuer Expense Ratio       AUM
# Ticker
# SPY     State Street Global Advisors         0.09%  $379.11B
# IVV                        Blackrock         0.03%  $310.04B
# VTI                         Vanguard         0.03%  $284.32B
# VOO                         Vanguard         0.03%  $282.26B
# QQQ                          Invesco         0.20%  $161.85B
# ...                              ...           ...       ...
# CVSB                  Morgan Stanley         0.24%        --
# CVLC                  Morgan Stanley            --        --
# CVMC                  Morgan Stanley         0.15%        --
# CVIE                  Morgan Stanley            --        --
# CDEI                  Morgan Stanley            --        --
#
# [3113 rows x 5 columns]
#          1 Year 5 Years 10 Years
# Ticker
# SPY      -9.58%  11.15%   12.44%
# IVV      -9.55%  11.17%   12.50%
# VTI     -10.06%  10.66%   12.08%
# VOO      -9.57%  11.17%   12.50%
# QQQ     -17.13%  14.91%   17.15%
# ...         ...     ...      ...
# CVSB         --      --       --
# CVLC         --      --       --
# CVMC         --      --       --
# CVIE         --      --       --
# CDEI         --      --       --
#
# [3113 rows x 3 columns]

# %%
base_de_dados_final
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# VOO                                  Vanguard S&P 500 ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVSB             Calvert Ultra-Short Investment Grade ETF
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# CVSB    Fixed Income: Global - Broad Market, Broad-bas...
# CVLC                             Equity: U.S. - Large Cap
# CVMC                               Equity: U.S. - Mid Cap
# CVIE        Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                             Equity: U.S. - Large Cap
#
#                               Issuer Expense Ratio       AUM   1 Year 5 Years  \
# Ticker
# SPY     State Street Global Advisors         0.09%  $379.11B   -9.58%  11.15%
# IVV                        Blackrock         0.03%  $310.04B   -9.55%  11.17%
# VTI                         Vanguard         0.03%  $284.32B  -10.06%  10.66%
# VOO                         Vanguard         0.03%  $282.26B   -9.57%  11.17%
# QQQ                          Invesco         0.20%  $161.85B  -17.13%  14.91%
# ...                              ...           ...       ...      ...     ...
# CVSB                  Morgan Stanley         0.24%        --       --      --
# CVLC                  Morgan Stanley            --        --       --      --
# CVMC                  Morgan Stanley         0.15%        --       --      --
# CVIE                  Morgan Stanley            --        --       --      --
# CDEI                  Morgan Stanley            --        --       --      --
#
#        10 Years
# Ticker
# SPY      12.44%
# IVV      12.50%
# VTI      12.08%
# VOO      12.50%
# QQQ      17.15%
# ...         ...
# CVSB         --
# CVLC         --
# CVMC         --
# CVIE         --
# CDEI         --
#
# [3113 rows x 8 columns]
